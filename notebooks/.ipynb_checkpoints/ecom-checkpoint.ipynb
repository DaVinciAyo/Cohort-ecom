# %%
#import libs
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read the file
data=pd.read_csv('/content/Dataset_ecommerce (2).csv')

# %%
#call 5 data to view the file
data.head()
# Out:
#   InvoiceNo          InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365  2010-12-01 08:26:00     17850.0    SC1734  Electronics        65
# 1    536365  2010-12-01 08:26:00     17850.0    SC2088    Furniture        95
# 2    536365  2010-12-01 08:26:00     17850.0    SC3463        Books        78
# 3    536365  2010-12-01 08:26:00     17850.0    SC6228         Toys        15
# 4    536365  2010-12-01 08:26:00     17850.0    SC2149         Toys        50
#
#    UnitPrice       Country
# 0      10.23         Egypt
# 1      19.61          Mali
# 2      61.49          Mali
# 3      24.73  South Africa
# 4      38.83        Rwanda

# %%
#check for missing data
data.isnull().sum()
# Out:
# InvoiceNo           0
# InvoiceDate         0
# CustomerID     135080
# StockCode           0
# Description         0
# Quantity            0
# UnitPrice           0
# Country             0
# dtype: int64

# %%
#drop row with missing data
data.dropna(inplace=True)

# %%
#check again for mising data
data.isnull().sum()
# Out:
# InvoiceNo      0
# InvoiceDate    0
# CustomerID     0
# StockCode      0
# Description    0
# Quantity       0
# UnitPrice      0
# Country        0
# dtype: int64

# %%
#create a new column
data['total_price']=data['Quantity'] * data['UnitPrice']

# %%
#check if total_price has been added to the dataframe
data.head()
# Out:
#   InvoiceNo          InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365  2010-12-01 08:26:00     17850.0    SC1734  Electronics        65
# 1    536365  2010-12-01 08:26:00     17850.0    SC2088    Furniture        95
# 2    536365  2010-12-01 08:26:00     17850.0    SC3463        Books        78
# 3    536365  2010-12-01 08:26:00     17850.0    SC6228         Toys        15
# 4    536365  2010-12-01 08:26:00     17850.0    SC2149         Toys        50
#
#    UnitPrice       Country  total_price
# 0      10.23         Egypt       664.95
# 1      19.61          Mali      1862.95
# 2      61.49          Mali      4796.22
# 3      24.73  South Africa       370.95
# 4      38.83        Rwanda      1941.50

# %%
price = data.groupby(['Country'])['total_price'].sum().reset_index()
price= price.sort_values(['total_price'], ascending=False)

# %%
#top 10 countries with highest amount bought
top10=price.head(10)
top10
# Out:
#          Country  total_price
# 9          Libya  37690362.35
# 19       Somalia  37663830.57
# 23          Togo  37592496.96
# 11          Mali  37508467.02
# 7          Ghana  37414593.40
# 15       Nigeria  37364243.60
# 6       Ethiopia  37228695.13
# 13    Mozambique  37145464.36
# 18  Sierra Leone  37140824.43
# 0        Algeria  37140683.52

# %%
plt.figure(figsize=(12,8))
plt.bar(data=top10, x='Country', height='total_price')
plt.show()

# %%
last10=price.tail(10)
last10
# Out:
#          Country  total_price
# 1          Benin  36921841.33
# 16        Rwanda  36864615.30
# 24       Tunisia  36837574.80
# 22      Tanzania  36820360.73
# 14         Niger  36808276.74
# 2   Burkina Faso  36671763.77
# 5          Egypt  36619734.48
# 25        Uganda  36598727.25
# 10    Madagascar  36524344.59
# 26        Zambia  36253058.16

# %%
plt.figure(figsize=(12,8))
plt.bar(data=last10, x='Country', height='total_price')
plt.show()

# %%
customer = data.groupby(['Country'])['CustomerID'].nunique().reset_index()
customer= customer.sort_values(['CustomerID'], ascending=False)

# %%
customer.head(10)
# Out:
#          Country  CustomerID
# 13    Mozambique        3072
# 1          Benin        3054
# 23          Togo        3053
# 15       Nigeria        3051
# 2   Burkina Faso        3049
# 18  Sierra Leone        3046
# 11          Mali        3044
# 0        Algeria        3043
# 17       Senegal        3040
# 14         Niger        3039

# %%
Ctop10=customer.head(10)
plt.figure(figsize=(20,8))
sns.barplot( x = 'Country', y = 'CustomerID', data=Ctop10,)
plt.title('top 10 country')
plt.xlabel('country')
plt.ylabel('CustomerID')
plt.show()

# %%
country_des = data.pivot_table(index='Country',
                                 columns='Description',
                                 aggfunc='size',
                                 fill_value=0)

# Show a few rows of the result
country_des
# Out:
# Description    Books  Cloths  Cosmetics  Electronics  Furniture  Jewelry  \
# Country
# Algeria         1422    1468       1452         1432       1401     1464
# Benin           1456    1476       1423         1459       1423     1502
# Burkina Faso    1428    1412       1448         1470       1465     1408
# Cameroon        1452    1442       1529         1378       1483     1488
# Cote d'Ivoire   1468    1509       1483         1456       1482     1459
# Egypt           1414    1426       1425         1478       1484     1451
# Ethiopia        1404    1458       1490         1422       1506     1473
# Ghana           1383    1476       1470         1526       1443     1462
# Kenya           1438    1441       1487         1383       1466     1512
# Libya           1460    1432       1475         1417       1474     1510
# Madagascar      1330    1435       1441         1498       1416     1424
# Mali            1424    1381       1377         1396       1445     1453
# Morocco         1448    1423       1453         1385       1454     1492
# Mozambique      1494    1490       1494         1418       1409     1475
# Niger           1419    1470       1367         1452       1517     1491
# Nigeria         1497    1479       1480         1477       1471     1412
# Rwanda          1468    1518       1412         1438       1435     1431
# Senegal         1476    1393       1461         1473       1477     1467
# Sierra Leone    1471    1442       1469         1499       1458     1502
# Somalia         1463    1455       1460         1412       1436     1444
# South Africa    1487    1437       1389         1395       1456     1450
# Sudan           1459    1474       1395         1417       1447     1447
# Tanzania        1470    1457       1463         1455       1448     1467
# Togo            1372    1491       1434         1422       1490     1482
# Tunisia         1423    1450       1403         1411       1445     1442
# Uganda          1355    1394       1408         1532       1484     1457
# Zambia          1403    1453       1444         1414       1402     1491
# Zimbabwe        1397    1448       1460         1489       1453     1461
#
# Description    Kitchenware  Shoes  Sports Equipment  Toys
# Country
# Algeria               1410   1512              1482  1449
# Benin                 1516   1409              1503  1443
# Burkina Faso          1512   1451              1408  1411
# Cameroon              1432   1464              1459  1492
# Cote d'Ivoire         1401   1419              1492  1476
# Egypt                 1442   1425              1440  1471
# Ethiopia              1430   1448              1482  1452
# Ghana                 1444   1404              1500  1496
# Kenya                 1457   1446              1436  1459
# Libya                 1498   1442              1398  1479
# Madagascar            1496   1484              1424  1371
# Mali                  1435   1442              1481  1485
# Morocco               1431   1491              1494  1459
# Mozambique            1434   1460              1498  1467
# Niger                 1374   1396              1517  1452
# Nigeria               1455   1377              1541  1525
# Rwanda                1515   1403              1487  1456
# Senegal               1461   1464              1461  1483
# Sierra Leone          1458   1496              1432  1457
# Somalia               1475   1554              1493  1464
# South Africa          1405   1512              1488  1450
# Sudan                 1494   1477              1433  1487
# Tanzania              1446   1408              1380  1396
# Togo                  1447   1456              1483  1483
# Tunisia               1489   1513              1415  1461
# Uganda                1514   1456              1453  1397
# Zambia                1434   1488              1424  1444
# Zimbabwe              1449   1472              1479  1464

# %%
most_desc= data['Description'].value_counts()

# %%
most_desc.head()
# Out:
# Description
# Jewelry             41017
# Sports Equipment    40983
# Toys                40829
# Furniture           40770
# Shoes               40769
# Name: count, dtype: int64

# %%
data['InvoiceDate']=pd.to_datetime(data['InvoiceDate'])

# %%
from datetime import datetime as dt

# %%
def get_month(x):
    return dt(x.year, x.month, 1)

# %%
data['InvoiceDate']= data['InvoiceDate'].apply(get_month)

# %%
data.head()
# Out:
#   InvoiceNo InvoiceDate  CustomerID StockCode  Description  Quantity  \
# 0    536365  2010-12-01     17850.0    SC1734  Electronics        65
# 1    536365  2010-12-01     17850.0    SC2088    Furniture        95
# 2    536365  2010-12-01     17850.0    SC3463        Books        78
# 3    536365  2010-12-01     17850.0    SC6228         Toys        15
# 4    536365  2010-12-01     17850.0    SC2149         Toys        50
#
#    UnitPrice       Country  total_price
# 0      10.23         Egypt       664.95
# 1      19.61          Mali      1862.95
# 2      61.49          Mali      4796.22
# 3      24.73  South Africa       370.95
# 4      38.83        Rwanda      1941.50
